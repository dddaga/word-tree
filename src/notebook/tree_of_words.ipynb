# %%
import numpy as np


context_dimension  = 2
graph_db_path      = 'word_graph' 


#def get_corpus(text_file):
    
    #filter_text() #only keep ([a-z],[0-9],{'.' ,',','!'})
    
    #return corpus #list of words


def get_ngram(indices, window_size = 2):  
    ngrams = []
    count  = 0
    for token in indices[:len(indices)-window_size+1]:
        ngrams.append(indices[count:count+window_size])  
        count = count+1  
    return ngrams

        

def touch_graph(graph,word):
    if word not in graph['words'].keys():
        graph['words'][word] = {'frequency':1 ,'connections':{} }
        
    else :
        graph['words'][word]['frequency'] += 1
    
    return graph
 
    
def touch_connection(graph,word_1,word_2):
    if word_2 not in graph['words'][word_1]['connections'].keys():
        context_vector      =  np.random.rand(context_dimension)
        unit_context_vector = context_vector / np.linalg.norm(context_vector)
        graph['words'][word_1]['connections'][word_2] = {'frequency':1 , 'context' : list(unit_context_vector) , 'update_count':0 , 'lock':False}
    else:
        graph['words'][word_1]['connections'][word_2]['frequency'] += 1
    return graph

def update_graph(corpus,graph=None):
    if graph == None:
        graph = {'words':{}}
    ngram = get_ngram(range(len(corpus)) ,2)
    for pair_index ,pair in  enumerate(ngram) :
        word_1 = corpus[pair[0]]
        word_2 = corpus[pair[1]]
        #print(pair_index,pair)
        if pair_index ==0 :
            graph = touch_graph(graph, word_1)
        graph = touch_graph(graph,word_2)
        graph = touch_connection(graph,word_1,word_2)
        
    return graph

# %%
sample_text_path = '/home/dhiraj/Documents/stuff/word-tree/sample_text.txt'

# %%
corpus_text = open(sample_text_path).read()
corpus_text = corpus_text.replace(',' ,'')
corpus_text = corpus_text.replace('.' ,'')

corpus = corpus_text.split(' ')
corpus[:5]
# Out:
# ['You', 'are', 'given', 'a', 'rotation']

# %%
import pyperclip
import json

graph = update_graph(corpus)
pyperclip.copy(json.dumps(graph))
#graph

# %%
json.dumps(graph)
# Out:
# '{"words": {"You": {"frequency": 1, "connections": {"are": {"frequency": 1, "context": [0.9498108557765388, 0.31282477243504697], "update_count": 0, "lock": false}}}, "are": {"frequency": 12, "connections": {"given": {"frequency": 4, "context": [0.9663094107367523, 0.25738322152306375], "update_count": 0, "lock": false}, "a": {"frequency": 4, "context": [0.9821834939693461, 0.18792441079904243], "update_count": 0, "lock": false}, "n!": {"frequency": 4, "context": [0.4878206834161939, 0.8729438589229881], "update_count": 0, "lock": false}}}, "given": {"frequency": 4, "connections": {"a": {"frequency": 4, "context": [0.2411037818917397, 0.9704993386692752], "update_count": 0, "lock": false}}}, "a": {"frequency": 40, "connections": {"rotation": {"frequency": 4, "context": [0.8636200845243441, 0.5041431836355271], "update_count": 0, "lock": false}, "square": {"frequency": 4, "context": [0.14830463072611544, 0.9889417255355295], "update_count": 0, "lock": false}, "structured": {"frequency": 4, "context": [0.32722437934855747, 0.944946668103524], "update_count": 0, "lock": false}, "set": {"frequency": 12, "context": [0.7554872900923454, 0.6551633036952881], "update_count": 0, "lock": false}, "natural": {"frequency": 4, "context": [0.9328978047097072, 0.3601412028188513], "update_count": 0, "lock": false}, "point": {"frequency": 4, "context": [0.40432938989678796, 0.9146134399109228], "update_count": 0, "lock": false}, "molecular": {"frequency": 4, "context": [0.2274966984149684, 0.9737788517986459], "update_count": 0, "lock": false}, "model": {"frequency": 4, "context": [0.9717926746955969, 0.23583680248845346], "update_count": 0, "lock": false}}}, "rotation": {"frequency": 4, "connections": {"angle": {"frequency": 4, "context": [0.995500926250027, 0.09475181177865838], "update_count": 0, "lock": false}}}, "angle": {"frequency": 4, "connections": {"and": {"frequency": 4, "context": [0.9119094569182735, 0.4103914501826514], "update_count": 0, "lock": false}}}, "and": {"frequency": 4, "connections": {"your": {"frequency": 4, "context": [0.6861523380137746, 0.7274578812812675], "update_count": 0, "lock": false}}}, "your": {"frequency": 4, "connections": {"task": {"frequency": 4, "context": [0.5863120767369479, 0.8100852724697613], "update_count": 0, "lock": false}}}, "task": {"frequency": 12, "connections": {"is": {"frequency": 4, "context": [0.9944205168754556, 0.10548855680665806], "update_count": 0, "lock": false}, "where": {"frequency": 4, "context": [0.6958652561209806, 0.7181723646337849], "update_count": 0, "lock": false}, "The": {"frequency": 4, "context": [0.13032027259192172, 0.991471949452715], "update_count": 0, "lock": false}}}, "is": {"frequency": 28, "connections": {"to": {"frequency": 4, "context": [0.6182745887253714, 0.7859621701688145], "update_count": 0, "lock": false}, "rotated": {"frequency": 4, "context": [0.916819637412102, 0.39930158083276096], "update_count": 0, "lock": false}, "a": {"frequency": 8, "context": [0.027042797741422073, 0.9996342766683807], "update_count": 0, "lock": false}, "no": {"frequency": 4, "context": [0.921875356947074, 0.38748654977135016], "update_count": 0, "lock": false}, "the": {"frequency": 4, "context": [0.8965098995500747, 0.443023701407402], "update_count": 0, "lock": false}, "in": {"frequency": 4, "context": [0.669379384821359, 0.7429207489202191], "update_count": 0, "lock": false}}}, "to": {"frequency": 32, "connections": {"draw": {"frequency": 4, "context": [0.08512429074740999, 0.9963703403477797], "update_count": 0, "lock": false}, "the": {"frequency": 12, "context": [0.7434129871033059, 0.6688326626340403], "update_count": 0, "lock": false}, "solve": {"frequency": 8, "context": [0.3657200170199512, 0.9307249159396812], "update_count": 0, "lock": false}, "permute": {"frequency": 4, "context": [0.8434618310388058, 0.5371891097003597], "update_count": 0, "lock": false}, "address": {"frequency": 4, "context": [0.2784190382028662, 0.9604597020001364], "update_count": 0, "lock": f ...

# %%
def get_ngram(indices, window_size = 2):  
    ngrams = []
    count  = 0
    for token in indices[:len(indices)-window_size+1]:
        ngrams.append(indices[count:count+window_size])  
        count = count+1  
    return ngrams

      

def touch_graph_db(collection,word):
    
    find_word = collection.find_one({'word':word})
    if find_word == None:
        print('new owrd !!!' , word)
        collection.insert_one( { 'word':word, 'frequency':1 ,'connections': [] })
    else :
        print('word node present',word)
        frequecny = find_word['frequency'] 
        collection.update_one({'word':word}, {"$set" : {'frequency' : frequecny + 1}})

    
def touch_connection_db(collection,word_1,word_2):
    
    find_connection = collection.find_one({'word': word_1,'connections.word': word_2}})
    
    if find_connection == None:
        context_vector      =  np.random.rand(context_dimension)
        unit_context_vector = context_vector / np.linalg.norm(context_vector)
        connection          = {'word':word_2 , \
                               'frequency':1 ,\
                               'context' : unit_context_vector , \
                               'update_count':0 , \
                               'lock':False}
        
        collection.update_one({'word':word_1}, {'$push' : {'connections' : connection}})       
    else:
        frequecny = ['frequency']
        update_key = 'connections.' + str(word_2) + '.frequency'
        collection.update_one({'word':word_1} ,{'$set': {update_key: frequecny +1 }})
        collection.find_one({'word':word_1 ,'connections' :{}})['frequency']



def update_graph_db(corpus,collection):
    
    ngram = get_ngram(range(len(corpus)) ,2)
    
    for pair_index ,pair in  enumerate(ngram) :
        word_1 = corpus[pair[0]]
        word_2 = corpus[pair[1]]
        if pair_index ==0 :
            touch_graph_db(collection, word_1)
        touch_graph_db(collection,word_2)
        touch_connection_db(collection,word_1,word_2)

# %%
def get_ngram(indices, window_size = 2):  
    ngrams = []
    count  = 0
    for token in indices[:len(indices)-window_size+1]:
        ngrams.append(indices[count:count+window_size])  
        count = count+1  
    return ngrams

      


    
def touch_connection_db(collection,word_1,word_2):
    
    find_connection = collection.find_one({'word': word_1,'connection': word_2})
    
    if find_connection == None:
        #print('connection {} {} is new'.format(word_1,word_2))
        context_vector      =  np.random.rand(context_dimension)
        unit_context_vector = context_vector / np.linalg.norm(context_vector)
        connection          = {'word':word_1 , \
                               'connection': word_2,\
                               'frequency':1 ,\
                               'context' : list(unit_context_vector) , \
                               'update_count':0 , \
                               'lock':False}
        
        collection.insert_one(connection)       
    else:
        #print('connection {} {} is old'.format(word_1,word_2))
        frequecny = find_connection['frequency']
        collection.update_one({'word': word_1,'connection': word_2} \
                              ,{'$set': {'frequency': frequecny +1 }})
        


def update_graph_db(corpus,collection):
    
    ngram = get_ngram(range(len(corpus)) ,2)
    
    for pair_index ,pair in  enumerate(ngram) :
        word_1 = corpus[pair[0]]
        word_2 = corpus[pair[1]]
        touch_connection_db(collection,word_1,word_2)
        print((index / len(corpus)) * 100 )

# %%
sample_text_path = '/home/dhiraj/Documents/stuff/word_tree/sample_text.txt'

# %%
corpus_text = open(sample_text_path).read()
corpus_text = corpus_text.replace(',' ,'')
corpus_text = corpus_text.replace('.' ,'')

corpus = corpus_text.split(' ')
corpus[:5]
# Out:
# ['You', 'are', 'given', 'a', 'rotation']

# %%
#import pyperclip
#import json

#graph = update_graph(corpus)
#pyperclip.copy(json.dumps(graph))

# %%
#corpus = ['You','who']

# %%
import pymongo

myclient = pymongo.MongoClient('mongodb://localhost:27017')

mydb = myclient["mydatabase"]
words = mydb.word3

# %%
context_dimension  = 75

update_graph_db(corpus,words)

# %%
for connection in words.find({'word':'set'}):
    print(connection)
# Out:
# {'_id': ObjectId('5fba95f02077310ef600d37f'), 'word': 'set', 'connection': 'since', 'frequency': 1, 'context': [0.9525462204761543, 0.30439398459331213], 'update_count': 0, 'lock': False}
# {'_id': ObjectId('5fba95f02077310ef600d397'), 'word': 'set', 'connection': 'of', 'frequency': 4, 'context': [0.8942630678126893, 0.4475416914056584], 'update_count': 0, 'lock': False}
# {'_id': ObjectId('5fba95f02077310ef600d3c7'), 'word': 'set', 'connection': 'freely', 'frequency': 1, 'context': [0.46091421980132585, 0.8874446923526756], 'update_count': 0, 'lock': False}
# {'_id': ObjectId('5fba95f02077310ef600d3dc'), 'word': 'set', 'connection': 'structure', 'frequency': 2, 'context': [0.6944520411527697, 0.7195389930634417], 'update_count': 0, 'lock': False}
# {'_id': ObjectId('5fba95f02077310ef600d3f2'), 'word': 'set', 'connection': 'prediction', 'frequency': 1, 'context': [0.6571424849815212, 0.7537663792132887], 'update_count': 0, 'lock': False}

# %%
pd.DataFrame(words.find({'word':'set'}))
# Out:
#                         _id word  connection  frequency  \
# 0  5fba95f02077310ef600d37f  set       since          1
# 1  5fba95f02077310ef600d397  set          of          4
# 2  5fba95f02077310ef600d3c7  set      freely          1
# 3  5fba95f02077310ef600d3dc  set   structure          2
# 4  5fba95f02077310ef600d3f2  set  prediction          1
#
#                                      context  update_count   lock
# 0  [0.9525462204761543, 0.30439398459331213]             0  False
# 1   [0.8942630678126893, 0.4475416914056584]             0  False
# 2  [0.46091421980132585, 0.8874446923526756]             0  False
# 3   [0.6944520411527697, 0.7195389930634417]             0  False
# 4   [0.6571424849815212, 0.7537663792132887]             0  False

# %%
import pandas as pd
import re

# %%
sample_text_path = '/home/dhiraj/Documents/stuff/word_tree/data/pride_and_prejudice_cleaned.txt'

# %%
corpus_text = open(sample_text_path).read()

# %%
corpus_text = corpus_text.replace('\n' , '')
match = re.search('  ', corpus_text)
while match!= None:
    corpus_text = corpus_text.replace('  ', ' ')
    match = re.search('  ',corpus_text)
    print( '__ found' )
# Out:
# __ found
# __ found
# __ found
# __ found

# %%
len(corpus_text)
# Out:
# 676389

# %%
corpus = corpus_text.split(' ')

# %%
corpus[:5]
# Out:
# ['It', 'is', 'a', 'truth', 'universally']

# %%
import pymongo
import time
myclient = pymongo.MongoClient('mongodb://localhost:27017')

mydb = myclient["mydatabase"]
words = mydb.p_and_p

# %%
start = time.time()
context_dimension  = 75

update_graph_db(corpus,words)

end = time.time() - start
# Out:
# connection It is is new
# connection is a is new
# connection a truth is new
# connection truth universally is new
# connection universally acknowledged is new
# connection acknowledged , is new
# connection , that is new
# connection that a is new
# connection a single is new
# connection single man is new
# connection man in is new
# connection in possession is new
# connection possession of is new
# connection of a is new
# connection a good is new
# connection good fortune is new
# connection fortune , is new
# connection , must is new
# connection must be is new
# connection be in is new
# connection in want is new
# connection want of is new
# connection of a is old
# connection a wife is new
# connection wife . is new
# connection . However is new
# connection However little is new
# connection little known is new
# connection known the is new
# connection the feelings is new
# connection feelings or is new
# connection or views is new
# connection views of is new
# connection of such is new
# connection such a is new
# connection a man is new
# connection man may is new
# connection may be is new
# connection be on is new
# connection on his is new
# connection his first is new
# connection first entering is new
# connection entering a is new
# connection a neighbourhood is new
# connection neighbourhood , is new
# connection , this is new
# connection this truth is new
# connection truth is is new
# connection is so is new
# connection so well is new
# connection well fixed is new
# connection fixed in is new
# connection in the is new
# connection the minds is new
# connection minds of is new
# connection of the is new
# connection the surrounding is new
# connection surrounding families is new
# connection families , is new
# connection , that is old
# connection that he is new
# connection he is is new
# connection is considered is new
# connection considered the is new
# connection the rightful is new
# connection rightful property is new
# connection property of is new
# connection of some is new
# connection some one is new
# connection one or is new
# connection or other is new
# connection other of is new
# connection of their is new
# connection their daughters is new
# connection daughters . is new
# connection . My is new
# connection My dear is new
# connection dear Mr is new
# connection Mr . is new
# connection . Bennet is new
# connection Bennet , is new
# connection , said is new
# connection said his is new
# connection his lady is new
# connection lady to is new
# connection to him is new
# connection him one is new
# connection one day is new
# connection day , is new
# connection , have is new
# connection have you is new
# connection you heard is new
# connection heard that is new
# connection that Netherfield is new
# connection Netherfield Park is new
# connection Park is is new
# connection is let is new
# connection let at is new
# connection at last is new
# connection last ? is new
# connection ? Mr is new
# connection Mr . is old
# connection . Bennet is old
# connection Bennet replied is new
# connection replied that is new
# connection that he is old
# connection he had is new
# connection had not is new
# connection not . is new
# connection . But is new
# connection But it is new
# connection it is is new
# connection is , is new
# connection , returned is new
# connection returned she is new
# connection she ; is new
# connection ; for is new
# connection for Mrs is new
# connection Mrs . is new
# connection . Long is new
# connection Long has is new
# connection has just is new
# connection just been is new
# connection been here is new
# connection here , is new
# connection , and is new
# connection and she is new
# connection she told is new
# connection told me is new
# connection me all is new
# connection all about is new
# connection about it is new
# connection it . is new
# connection . Mr is new
# connection Mr . is old
# connection . Bennet is old
# connection Bennet made is new
# connection made no is new
# connection no answer is new
# connection answer . is new
# connection . Do is new
# connection Do you is new
# connection you not is new
# connection not want is new
# connection want to is new
# connection to know is new
# connection know who is new
# connection who has is new
# connection has taken is new
# connection taken it is new
# connection it ? is new
# connection ? cried is new
# connection cried his is new
# connection his wife is new
# connection wife impatiently is new
# connection impatiently . is new
# connection . _You_ is new
# connection _You_ want is new
# connection want to is old
# connection to tell is new
# connection tell me is new
# connection me , is new
# connection , and is old
# connection and I is new
# connection I have is new
# connection have no is new
# connection no objection is new
# connection objection to is new
# connection to hearing is new
# connection hearing it is new
# connection it . is old
# connection . This is new
# connection This was is new
# connection was invitation is new
# connection invitation enough is new
# connection enough . is new
# connection . Why is new
# connection Why , is new
# connection , my is new
# connection my dear is new
# connection dear , is new
# connection , you is new
# connection you must is new
# connection must know is new
# connection know , is new
# connection , Mrs is new
# connection Mrs . is old
# connection . Long is old
# connection Long says is new
# connection says that is new
# connection that Netherfield is old
# connection Netherfield is is new
# connection is taken is new
# connection taken by is new
# connection by a is new
# connection a young is new
# connection young man is new
# connection man of is new
# connection of large is new
# connection large fortune is new
# connection fortune from is new
# connection from the is new
# connection the north is new
# connection north of is new
# connection of England is new
# connection England ; is new
# connection ; that is new
# connection that he is old
# connection he came is new
# connection came down is new
# connection down on is new
# connection on Monday is new
# connection Monday in is new
# connection in a is new
# connection a chaise is new
# connection chaise and is new
# connection and four is new
# connection four to is new
# connection to see is new
# connection see the is new
# connection the place is new
# connection place , is new
# connection , and is old
# connection and was is new
# connection was so is new
# connection so much is new
# connection much delighted is new
# connection delighted with is new
# connection with it is new
# connection it , is new
# connection , that is old
# connection that he is old
# connection he agreed is new
# connection agreed with is new
# connection with Mr is new
# connection Mr . is old
# connection . Morris is new
# connection Morris immediately is new
# connection immediately ; is new
# connection ; that is old
# connection that he is old
# connection he is is old
# connection is to is new
# connection to take is new
# connection take possession is new
# connection possession before is new
# connection before Michaelmas is new
# connection Michaelmas , is new
# connection , and is old
# connection and some is new
# connection some of is new
# connection of his is new
# connection his servants is new
# connection servants are is new
# connection are to is new
# connection to be is new
# connection be in is old
# connection in the is old
# connection the house is new
# connection house by is new
# connection by the is new
# connection the end is new
# connection end of is new
# connection of next is new
# connection next week is new
# connection week . is new
# connection . What is new
# connection What is is new
# connection is his is new
# connection his name is new
# connection name ? is new
# connection ? Bingley is new
# connection Bingley . is new
# connection . Is is new
# connection Is he is new
# connection he married is new
# connection married or is new
# connection or single is new
# connection single ? is new
# connection ? Oh is new
# connection Oh ! is new
# connection ! Single is new
# connection Single , is new
# connection , my is old
# connection my dear is old
# connection dear , is old
# connection , to is new
# connection to be is old
# connection be sure is new
# connection sure ! is new
# connection ! A is new
# connection A single is new
# connection single man is old
# connection man of is old
# connection of large is old
# connection large fortune is old
# connection fortune ; is new
# connection ; four is new
# connection four or is new
# connection or five is new
# connection five thousand is new
# connection thousand a is new
# connection a year is new
# connection year . is new
# connection . What is old
# connection What a is new
# connection a fine is new
# connection fine thing is new
# connection thing for is new
# connection for our is new
# connection our girls is new
# connection girls ! is new
# connection ! How is new
# connection How so is new
# connection so ? is new
# connection ? How is new
# connection How can is new
# connection can it is new
# connection it affect is new
# connection affect them is new
# connection them ? is new
# connection ? My is new
# connection My dear is old
# connection dear Mr is old
# connection Mr . is old
# connection . Bennet is old
# connection Bennet , is old
# connection , replied is new
# connection replied his is new
# connection his wife is old
# connection wife , is new
# connection , how is new
# connection how can is new
# connection can you is new
# connection you be is new
# connection be so is new
# connection so tiresome is new
# connection tiresome ! is new
# connection ! You is new
# connection You must is new
# connection must know is old
# connection know that is new
# connection that I is new
# connection I am is new
# connection am thinking is new
# connection thinking of is new
# connection of his is old
# connection his marrying is new
# connection marrying one is new
# connection one of is new
# connection of them is new
# connection them . is new
# connection . Is is old
# connection Is that is new
# connection that his is new
# connection his design is new
# connection design in is new
# connection in settling is new
# connection settling here is new
# connection here ? is new
# connection ? Design is new
# connection Design ! is new
# connection ! Nonsense is new
# connection Nonsense , is new
# connection , how is old
# connection how can is old
# connection can you is old
# connection you talk is new
# connection talk so is new
# connection so ! is new
# connection ! But is new
# connection But it is old
# connection it is is old
# connection is very is new
# connection very likely is new
# connection likely that is new
# connection that he is old
# connection he _may_ is new
# connection _may_ fall is new
# connection fall in is new
# connection in love is new
# connection love with is new
# connection with one is new
# connection one of is old
# connection of them is old
# connection them , is new
# connection , and is old
# connection and therefore is new
# connection therefore you is new
# connection you must is old
# connection must visit is new
# connection visit him is new
# connection him as is new
# connection as soon is new
# connection soon as is new
# connection as he is new
# connection he comes is new
# connection comes . is new
# connection . I is new
# connection I see is new
# connection see no is new
# connection no occasion is new
# connection occasion for is new
# connection for that is new
# connection that . is new
# connection . You is new
# connection You and is new
# connection and the is new
# connection the girls is new
# connection girls may is new
# connection may go is new
# connection go , is new
# connection , or is new
# connection or you is new
# connection you may is new
# connection may send is new
# connection send them is new
# connection them by is new
# connection by themselves is new
# connection themselves , is new
# connection , which is new
# connection which perhaps is new
# connection perhaps will is new
# connection will be is new
# connection be still is new
# connection still better is new
# connection better , is new
# connection , for is new
# connection for as is new
# connection as you is new
# connection you are is new
# connection are as is new
# connection as handsome is new
# connection handsome as is new
# connection as any is new
# connection any of is new
# connection of them is old
# connection them , is old
# connection , Mr is new
# connection Mr . is old
# connection . Bingley is new
# connection Bingley may is new
# connection may like is new
# connection like you is new
# connection you the is new
# connection the best is new
# connection best of is new
# connection of the is old
# connection the party is new
# connection party . is new
# connection . My is old
# connection My dear is old
# connection dear , is old
# connection , you is old
# connection you flatter is new
# connection flatter me is new
# connection me . is new
# connection . I is old
# connection I certainly is new
# connection certainly _have_ is new
# connection _have_ had is new
# connection had my is new
# connection my share is new
# connection share of is new
# connection of beauty is new
# connection beauty , is new
# connection , but is new
# connection but I is new
# connection I do is new
# connection do not is new
# connection not pretend is new
# connection pretend to is new
# connection to be is old
# connection be anything is new
# connection anything extraordinary is new
# connection extraordinary now is new
# connection now . is new
# connection . When is new
# connection When a is new
# connection a woman is new
# connection woman has is new
# connection has five is new
# connection five grown-up is new
# connection grown-up daughters is new
# connection daughters , is new
# connection , she is new
# connection she ought is new
# connection ought to is new
# connection to give is new
# connection give over is new
# connection over thinking is new
# connection thinking of is old
# connection of her is new
# connection her own is new
# connection own beauty is new
# connection beauty . is new
# connection . In is new
# connection In such is new
# connection such cases is new
# connection cases , is new
# connection , a is new
# connection a woman is old
# connection woman has is old
# connection has not is new
# connection not often is new
# connection often much is new
# connection much beauty is new
# connection beauty to is new
# connection to think is new
# connection think of is new
# connection of . is new
# connection . But is old
# connection But , is new
# connection , my is old
# connection my dear is old
# connection dear , is old
# connection , you is old
# connection you must is old
# connection must indeed is new
# connection indeed go is new
# connection go and is new
# connection and see is new
# connection see Mr is new
# connection Mr . is old
# connection . Bingley is old
# connection Bingley when is new
# connection when he is new
# connection he comes is old
# connection comes into is new
# connection into the is new
# connection the neighbourhood is new
# connection neighbourhood . is new
# connection . It is new
# connection It is is old
# connection is more is new
# connection more than is new
# connection than I is new
# connection I engage is new
# connection engage for is new
# connection for , is new
# connection , I is new
# connection I assure is new
# connection assure you is new
# connection you . is new
# connection . But is old
# connection But consider is new
# connection consider your is new
# connection your daughters is new
# connection daughters . is old
# connection . Only is new
# connection Only think is new
# connection think what is new
# connection what an is new
# connection an establishment is new
# connection establishment it is new
# connection it would is new
# connection would be is new
# connection be for is new
# connection for one is new
# connection one of is old
# connection of them is old
# connection them . is old
# connection . Sir is new
# connection Sir William is new
# connection William and is new
# connection and Lady is new
# connection Lady Lucas is new
# connection Lucas are is new
# connection are determined is new
# connection determined to is new
# connection to go is new
# connection go , is old
# connection , merely is new
# connection merely on is new
# connection on that is new
# connection that account is new
# connection account , is new
# connection , for is old
# connection for in is new
# connection in general is new
# connection general , is new
# connection , you is old
# connection you know is new
# connection know , is old
# connection , they is new
# connection they visit is new
# connection visit no is new
# connection no newcomers is new
# connection newcomers . is new
# connection . Indeed is new
# connection Indeed you is new
# connection you must is old
# connection must go is new
# connection go , is old
# connection , for is old
# connection for it is new
# connection it will is new
# connection will be is old
# connection be impossible is new
# connection impossible for is new
# connection for _us_ is new
# connection _us_ to is new
# connection to visit is new
# connection visit him is old
# connection him if is new
# connection if you is new
# connection you do is new
# connection do not is old
# connection not . is old
# connection . You is old
# connection You are is new
# connection are over-scrupulous is new
# connection over-scrupulous , is new
# connection , surely is new
# connection surely . is new
# connection . I is old
# connection I dare is new
# connection dare say is new
# connection say Mr is new
# connection Mr . is old
# connection . Bingley is old
# connection Bingley will is new
# connection will be is old
# connection be very is new
# connection very glad is new
# connection glad to is new
# connection to see is old
# connection see you is new
# connection you ; is new
# connection ; and is new
# connection and I is old
# connection I will is new
# connection will send is new
# connection send a is new
# connection a few is new
# connection few lines is new
# connection lines by is new
# connection by you is new
# connection you to is new
# connection to assure is new
# connection assure him is new
# connection him of is new
# connection of my is new
# connection my hearty is new
# connection hearty consent is new
# connection consent to is new
# connection to his is new
# connection his marrying is old
# connection marrying whichever is new
# connection whichever he is new
# connection he chooses is new
# connection chooses of is new
# connection of the is old
# connection the girls is old
# connection girls ; is new
# connection ; though is new
# connection though I is new
# connection I must is new
# connection must throw is new
# connection throw in is new
# connection in a is old
# connection a good is old
# connection good word is new
# connection word for is new
# connection for my is new
# connection my little is new
# connection little Lizzy is new
# connection Lizzy . is new
# connection . I is old
# connection I desire is new
# connection desire you is new
# connection you will is new
# connection will do is new
# connection do no is new
# connection no such is new
# connection such thing is new
# connection thing . is new
# connection . Lizzy is new
# connection Lizzy is is new
# connection is not is new
# connection not a is new
# connection a bit is new
# connection bit better is new
# connection better than is new
# connection than the is new
# connection the others is new
# connection others ; is new
# connection ; and is old
# connection and I is old
# connection I am is old
# connection am sure is new
# connection sure she is new
# connection she is is new
# connection is not is old
# connection not half is new
# connection half so is new
# connection so handsome is new
# connection handsome as is old
# connection as Jane is new
# connection Jane , is new
# connection , nor is new
# connection nor half is new
# connection half so is old
# connection so good-humoured is new
# connection good-humoured as is new
# connection as Lydia is new
# connection Lydia . is new
# connection . But is old
# connection But you is new
# connection you are is old
# connection are always is new
# connection always giving is new
# connection giving _her_ is new
# connection _her_ the is new
# connection the preference is new
# connection preference . is new
# connection . They is new
# connection They have is new
# connection have none is new
# connection none of is new
# connection of them is old
# connection them much is new
# connection much to is new
# connection to recommend is new
# connection recommend them is new
# connection them , is old
# connection , replied is old
# connection replied he is new
# connection he ; is new
# connection ; they is new
# connection they are is new
# connection are all is new
# connection all silly is new
# connection silly and is new
# connection and ignorant is new
# connection ignorant like is new
# connection like other is new
# connection other girls is new
# connection girls ; is old
# connection ; but is new
# connection but Lizzy is new
# connection Lizzy has is new
# connection has something is new
# connection something more is new
# connection more of is new
# connection of quickness is new
# connection quickness than is new
# connection than her is new
# connection her sisters is new
# connection sisters . is new
# connection . Mr is old
# connection Mr . is old
# connection . Bennet is old
# connection Bennet , is old
# connection , how is old
# connection how can is old
# connection can you is old
# connection you abuse is new
# connection abuse your is new
# connection your own is new
# connection own children is new
# connection children in is new
# connection in such is new
# connection such a is old
# connection a way is new
# connection way ? is new
# connection ? You is new
# connection You take is new
# connection take delight is new
# connection delight in is new
# connection in vexing is new
# connection vexing me is new
# connection me . is old
# connection . You is old
# connection You have is new
# connection have no is old
# connection no compassion is new
# connection compassion for is new
# connection for my is old
# connection my poor is new
# connection poor nerves is new
# connection nerves . is new
# connection . You is old
# connection You mistake is new
# connection mistake me is new
# connection me , is old
# connection , my is old
# connection my dear is old
# connection dear . is new
# connection . I is old
# connection I have is old
# connection have a is new
# connection a high is new
# connection high respect is new
# connection respect for is new
# connection for your is new
# connection your nerves is new
# connection nerves . is old
# connection . They is old
# connection They are is new
# connection are my is new
# connection my old is new
# connection old friends is new
# connection friends . is new
# connection . I is old
# connection I have is old
# connection have heard is new
# connection heard you is new
# connection you mention is new
# connection mention them is new
# connection them with is new
# connection with consideration is new
# connection consideration these is new
# connection these last is new
# connection last twenty is new
# connection twenty years is new
# connection years at is new
# connection at least is new
# connection least . is new
# connection . Ah is new
# connection Ah , is new
# connection , you is old
# connection you do is old
# connection do not is old
# connection not know is new
# connection know what is new
# connection what I is new
# connection I suffer is new
# connection suffer . is new
# connection . But is old
# connection But I is new
# connection I hope is new
# connection hope you is new
# connection you will is old
# connection will get is new
# connection get over is new
# connection over it is new
# connection it , is old
# connection , and is old
# connection and live is new
# connection live to is new
# connection to see is old
# connection see many is new
# connection many young is new
# connection young men is new
# connection men of is new
# connection of four is new
# connection four thousand is new
# connection thousand a is old
# connection a year is old
# connection year come is new
# connection come into is new
# connection into the is old
# connection the neighbourhood is old
# connection neighbourhood . is old
# connection . It is old
# connection It will is new
# connection will be is old
# connection be no is new
# connection no use is new
# connection use to is new
# connection to us is new
# connection us , is new
# connection , if is new
# connection if twenty is new
# connection twenty such is new
# connection such should is new
# connection should come is new
# connection come , is new
# connection , since is new
# connection since you is new
# connection you will is old
# connection will not is new
# connection not visit is new
# connection visit them is new
# connection them . is old
# connection . Depend is new
# connection Depend upon is new
# connection upon it is new
# connection it , is old
# connection , my is old
# connection my dear is old
# connection dear , is old
# connection , that is old
# connection that when is new
# connection when there is new
# connection there are is new
# connection are twenty is new
# connection twenty , is new
# connection , I is old
# connection I will is old
# connection will visit is new
# connection visit them is old
# connection them all is new
# connection all . is new
# connection . Mr is old
# connection Mr . is old
# connection . Bennet is old
# connection Bennet was is new
# connection was so is old
# connection so odd is new
# connection odd a is new
# connection a mixture is new
# connection mixture of is new
# connection of quick is new
# connection quick parts is new
# connection parts , is new
# connection , sarcastic is new
# connection sarcastic humour is new
# connection humour , is new
# connection , reserve is new
# connection reserve , is new
# connection , and is old
# connection and caprice is new
# connection caprice , is new
# connection , that is old
# connection that the is new
# connection the experience is new
# connection experience of is new
# connection of three-and-twenty is new
# connection three-and-twenty years is new
# connection years had is new
# connection had been is new
# connection been insufficient is new
# connection insufficient to is new
# connection to make is new
# connection make his is new
# connection his wife is old
# connection wife understand is new
# connection understand his is new
# connection his character is new
# connection character . is new
# connection . _Her_ is new
# connection _Her_ mind is new
# connection mind was is new
# connection was less is new
# connection less difficult is new
# connection difficult to is new
# connection to develop is new
# connection develop . is new
# connection . She is new
# connection She was is new
# connection was a is new
# connection a woman is old
# connection woman of is new
# connection of mean is new
# connection mean understanding is new
# connection understanding , is new
# connection , little is new
# connection little information is new
# connection information , is new
# connection , and is old
# connection and uncertain is new
# connection uncertain temper is new
# connection temper . is new
# connection . When is old
# connection When she is new
# connection she was is new
# connection was discontented is new
# connection discontented , is new
# connection , she is old
# connection she fancied is new
# connection fancied herself is new
# connection herself nervous is new
# connection nervous . is new
# connection . The is new
# connection The business is new
# connection business of is new
# connection of her is old
# connection her life is new
# connection life was is new
# connection was to is new
# connection to get is new
# connection get her is new
# connection her daughters is new
# connection daughters married is new
# connection married ; is new
# connection ; its is new
# connection its solace is new
# connection solace was is new
# connection was visiting is new
# connection visiting and is new
# connection and news is new
# connection news . is new
# connection . Mr is old
# connection Mr . is old
# connection . Bennet is old
# connection Bennet was is old
# connection was among is new
# connection among the is new
# connection the earliest is new
# connection earliest of is new
# connection of those is new
# connection those who is new
# connection who waited is new
# connection waited on is new
# connection on Mr is new
# connection Mr . is old
# connection . Bingley is old
# connection Bingley . is old
# connection . He is new
# connection He had is new
# connection had always is new
# connection always intended is new
# connection intended to is new
# connection to visit is old
# connection visit him is old
# connection him , is new
# connection , though is new
# connection though to is new
# connection to the is new
# connection the last is new
# connection last always is new
# connection always assuring is new
# connection assuring his is new
# connection his wife is old
# connection wife that is new
# connection that he is old
# connection he should is new
# connection should not is new
# connection not go is new
# connection go ; is new
# connection ; and is old
# connection and till is new
# connection till the is new
# connection the evening is new
# connection evening after is new
# connection after the is new
# connection the visit is new
# connection visit was is new
# connection was paid is new
# connection paid she is new
# connection she had is new
# connection had no is new
# connection no knowledge is new
# connection knowledge of is new
# connection of it is new
# connection it . is old
# connection . It is old
# connection It was is new
# connection was then is new
# connection then disclosed is new
# connection disclosed in is new
# connection in the is old
# connection the following is new
# connection following manner is new
# connection manner . is new
# connection . Observing is new
# connection Observing his is new
# connection his second is new
# connection second daughter is new
# connection daughter employed is new
# connection employed in is new
# connection in trimming is new
# connection trimming a is new
# connection a hat is new
# connection hat , is new
# connection , he is new
# connection he suddenly is new
# connection suddenly addressed is new
# connection addressed her is new
# connection her with: is new
# connection with: I is new
# connection I hope is old
# connection hope Mr is new
# connection Mr . is old
# connection . Bingley is old
# connection Bingley will is old
# connection will like is new
# connection like it is new
# connection it , is old
# connection , Lizzy is new
# connection Lizzy . is old
# connection . We is new
# connection We are is new
# connection are not is new
# connection not in is new
# connection in a is old
# connection a way is old
# connection way to is new
# connection to know is old
# connection know _what_ is new
# connection _what_ Mr is new
# connection Mr . is old
# connection . Bingley is old
# connection Bingley likes is new
# connection likes , is new
# connection , said is old
# connection said her is new
# connection her mother is new
# connection mother resentfully is new
# connection resentfully , is new
# connection , since is old
# connection since we is new
# connection we are is new
# connection are not is old
# connection not to is new
# connection to visit is old
# connection visit . is new
# connection . But is old
# connection But you is old
# connection you forget is new
# connection forget , is new
# connection , mamma is new
# connection mamma , is new
# connection , said is old
# connection said Elizabeth is new
# connection Elizabeth , is new
# connection , that is old
# connection that we is new
# connection we shall is new
# connection shall meet is new
# connection meet him is new
# connection him at is new
# connection at the is new
# connection the assemblies is new
# connection assemblies , is new
# connection , and is old
# connection and that is new
# connection that Mrs is new
# connection Mrs . is old
# connection . Long is old
# connection Long promised is new
# connection promised to is new
# connection to introduce is new
# connection introduce him is new
# connection him . is new
# connection . I is old
# connection I do is old
# connection do not is old
# connection not believe is new
# connection believe Mrs is new
# connection Mrs . is old
# connection . Long is old
# connection Long will is new
# connection will do is old
# connection do any is new
# connection any such is new
# connection such thing is old
# connection thing . is old
# connection . She is old
# connection She has is new
# connection has two is new
# connection two nieces is new
# connection nieces of is new
# connection of her is old
# connection her own is old
# connection own . is new
# connection . She is old
# connection She is is new
# connection is a is old
# connection a selfish is new
# connection selfish , is new
# connection , hypocritical is new
# connection hypocritical woman is new
# connection woman , is new
# connection , and is old
# connection and I is old
# connection I have is old
# connection have no is old
# connection no opinion is new
# connection opinion of is new
# connection of her is old
# connection her . is new
# connection . No is new
# connection No more is new
# connection more have is new
# connection have I is new
# connection I , is new
# connection , said is old
# connection said Mr is new
# connection Mr . is old
# connection . Bennet is old
# connection Bennet ; is new
# connection ; and is old
# connection and I is old
# connection I am is old
# connection am glad is new
# connection glad to is old
# connection to find is new
# connection find that is new
# connection that you is new
# connection you do is old
# connection do not is old
# connection not depend is new
# connection depend on is new
# connection on her is new
# connection her serving is new
# connection serving you is new
# connection you . is old
# connection . Mrs is new
# connection Mrs . is old
# connection . Bennet is old
# connection Bennet deigned is new
# connection deigned not is new
# connection not to is old
# connection to make is old
# connection make any is new
# connection any reply is new
# connection reply , is new
# connection , but is old
# connection but , is new
# connection , unable is new
# connection unable to is new
# connection to contain is new
# connection contain herself is new
# connection herself , is new
# connection , began is new
# connection began scolding is new
# connection scolding one is new
# connection one of is old
# connection of her is old
# connection her daughters is old
# connection daughters . is old
# connection . Don’t is new
# connection Don’t keep is new
# connection keep coughing is new
# connection coughing so is new
# connection so , is new
# connection , Kitty is new
# connection Kitty , is new
# connection , for is old
# connection for Heaven’s is new
# connection Heaven’s sake is new
# connection sake ! is new
# connection ! Have is new
# connection Have a is new
# connection a little is new
# connection little compassion is new
# connection compassion on is new
# connection on my is new
# connection my nerves is new
# connection nerves . is old
# connection . You is old
# connection You tear is new
# connection tear them is new
# connection them to is new
# connection to pieces is new
# connection pieces . is new
# connection . Kitty is new
# connection Kitty has is new
# connection has no is new
# connection no discretion is new
# connection discretion in is new
# connection in her is new
# connection her coughs is new
# connection coughs , is new
# connection , said is old
# connection said her is old
# connection her father is new
# connection father ; is new
# connection ; she is new
# connection she times is new
# connection times them is new
# connection them ill is new
# connection ill . is new
# connection . I is old
# connection I do is old
# connection do not is old
# connection not cough is new
# connection cough for is new
# connection for my is old
# connection my own is new
# connection own amusement is new
# connection amusement , is new
# connection , replied is old
# connection replied Kitty is new
# connection Kitty fretfully is new
# connection fretfully . is new
# connection . When is old
# connection When is is new
# connection is your is new
# connection your next is new
# connection next ball is new
# connection ball to is new
# connection to be is old
# connection be , is new
# connection , Lizzy is old
# connection Lizzy ? is new
# connection ? To-morrow is new
# connection To-morrow fortnight is new
# connection fortnight . is new
# connection . Aye is new
# connection Aye , is new
# connection , so is new
# connection so it is new
# connection it is is old
# connection is , is old
# connection , cried is new
# connection cried her is new
# connection her mother is old
# connection mother , is new
# connection , and is old
# connection and Mrs is new
# connection Mrs . is old
# connection . Long is old
# connection Long does is new
# connection does not is new
# connection not come is new
# connection come back is new
# connection back till is new
# connection till the is old
# connection the day is new
# connection day before is new
# connection before ; is new
# connection ; so is new
# connection so it is old
# connection it will is old
# connection will be is old
# connection be impossible is old
# connection impossible for is old
# connection for her is new
# connection her to is new
# connection to introduce is old
# connection introduce him is old
# connection him , is old
# connection , for is old
# connection for she is new
# connection she will is new
# connection will not is old
# connection not know is old
# connection know him is new
# connection him herself is new
# connection herself . is new
# connection . Then is new
# connection Then , is new
# connection , my is old
# connection my dear is old
# connection dear , is old
# connection , you is old
# connection you may is old
# connection may have is new
# connection have the is new
# connection the advantage is new
# connection advantage of is new
# connection of your is new
# connection your friend is new
# connection friend , is new
# connection , and is old
# connection and introduce is new
# connection introduce Mr is new
# connection Mr . is old
# connection . Bingley is old
# connection Bingley to is new
# connection to _her_ is new
# connection _her_ . is new
# connection . Impossible is new
# connection Impossible , is new
# connection , Mr is old
# connection Mr . is old
# connection . Bennet is old
# connection Bennet , is old
# connection , impossible is new
# connection impossible , is new
# connection , when is new
# connection when I is new
# connection I am is old
# connection am not is new
# connection not acquainted is new
# connection acquainted with is new
# connection with him is new
# connection him myself is new
# connection myself ; is new
# connection ; how is new
# connection how can is old
# connection can you is old
# connection you be is old
# connection be so is old
# connection so teasing is new
# connection teasing ? is new
# connection ? I is new
# connection I honour is new
# connection honour your is new
# connection your circumspection is new
# connection circumspection . is new
# connection . A is new
# connection A fortnight’s is new
# connection fortnight’s acquaintance is new
# connection acquaintance is is new
# connection is certainly is new
# connection certainly very is new
# connection very little is new
# connection little . is new
# connection . One is new
# connection One cannot is new
# connection cannot know is new
# connection know what is old
# connection what a is new
# connection a man is old
# connection man really is new
# connection really is is new
# connection is by is new
# connection by the is old
# connection the end is old
# connection end of is old
# connection of a is old
# connection a fortnight is new
# connection fortnight . is old
# connection . But is old
# connection But if is new
# connection if _we_ is new
# connection _we_ do is new
# connection do not is old
# connection not venture is new
# connection venture somebody is new
# connection somebody else is new
# connection else will is new
# connection will ; is new
# connection ; and is old
# connection and after is new
# connection after all is new
# connection all , is new
# connection , Mrs is old
# connection Mrs . is old
# connection . Long is old
# connection Long and is new
# connection and her is new
# connection her nieces is new
# connection nieces must is new
# connection must stand is new
# connection stand their is new
# connection their chance is new
# connection chance ; is new
# connection ; and is old
# connection and , is new
# connection , therefore is new
# connection therefore , is new
# connection , as is new
# connection as she is new
# connection she will is old
# connection will think is new
# connection think it is new
# connection it an is new
# connection an act is new
# connection act of is new
# connection of kindness is new
# connection kindness , is new
# connection , if is old
# connection if you is old
# connection you decline is new
# connection decline the is new
# connection the office is new
# connection office , is new
# connection , I is old
# connection I will is old
# connection will take is new
# connection take it is new
# connection it on is new
# connection on myself is new
# connection myself . is new
# connection . The is old
# connection The girls is new
# connection girls stared is new
# connection stared at is new
# connection at their is new
# connection their father is new
# connection father . is new
# connection . Mrs is old
# connection Mrs . is old
# connection . Bennet is old
# connection Bennet said is new
# connection said only is new
# connection only , is new
# connection , Nonsense is new
# connection Nonsense , is old
# connection , nonsense is new
# connection nonsense ! is new
# connection ! What is new
# connection What can is new
# connection can be is new
# connection be the is new
# connection the meaning is new
# connection meaning of is new
# connection of that is new
# connection that emphatic is new
# connection emphatic exclamation is new
# connection exclamation ? is new
# connection ? cried is old
# connection cried he is new
# connection he . is new
# connection . Do is old
# connection Do you is old
# connection you consider is new
# connection consider the is new
# connection the forms is new
# connection forms of is new
# connection of introduction is new
# connection introduction , is new
# connection , and is old
# connection and the is old
# connection the stress is new
# connection stress that is new
# connection that is is new
# connection is laid is new
# connection laid on is new
# connection on them is new
# connection them , is old
# connection , as is old
# connection as nonsense is new
# connection nonsense ? is new
# connection ? I is old
# connection I cannot is new
# connection cannot quite is new
# connection quite agree is new
# connection agree with is new
# connection with you is new
# connection you _there_ is new
# connection _there_ . is new
# connection . What is old
# connection What say is new
# connection say you is new
# connection you , is new
# connection , Mary is new
# connection Mary ? is new
# connection ? For is new
# connection For you is new
# connection you are is old
# connection are a is new
# connection a young is old
# connection young lady is new
# connection lady of is new
# connection of deep is new
# connection deep reflection is new
# connection reflection , is new
# connection , I is old
# connection I know is new
# connection know , is old
# connection , and is old
# connection and read is new
# connection read great is new
# connection great books is new
# connection books and is new
# connection and make is new
# connection make extracts is new
# connection extracts . is new
# connection . Mary is new
# connection Mary wished is new
# connection wished to is new
# connection to say is new
# connection say something is new
# connection something sensible is new
# connection sensible , is new
# connection , but is old
# connection but knew is new
# connection knew not is new
# connection not how is new
# connection how . is new
# connection . While is new
# connection While Mary is new
# connection Mary is is new
# connection is adjusting is new
# connection adjusting her is new
# connection her ideas is new
# connection ideas , is new
# connection , he is old
# connection he continued is new
# connection continued , is new
# connection , let is new
# connection let us is new
# connection us return is new
# connection return to is new
# connection to Mr is new
# connection Mr . is old
# connection . Bingley is old
# connection Bingley . is old
# connection . I is old
# connection I am is old
# connection am sick is new
# connection sick of is new
# connection of Mr is new
# connection Mr . is old
# connection . Bingley is old
# connection Bingley , is new
# connection , cried is old
# connection cried his is old
# connection his wife is old
# connection wife . is old
# connection . I is old
# connection I am is old
# connection am sorry is new
# connection sorry to is new
# connection to hear is new
# connection hear _that_ is new
# connection _that_ ; is new
# connection ; but is old
# connection but why is new
# connection why did is new
# connection did not is new
# connection not you is new
# connection you tell is new
# connection tell me is old
# connection me that is new
# connection that before is new
# connection before ? is new
# connection ? If is new
# connection If I is new
# connection I had is new
# connection had known is new
# connection known as is new
# connection as much is new
# connection much this is new
# connection this morning is new
# connection morning I is new
# connection I certainly is old
# connection certainly would is new
# connection would not is new
# connection not have is new
# connection have called is new
# connection called on is new
# connection on him is new
# connection him . is old
# connection . It is old
# connection It is is old
# connection is very is old
# connection very unlucky is new
# connection unlucky ; is new
# connection ; but is old
# connection but as is new
# connection as I is new
# connection I have is old
# connection have actually is new
# connection actually paid is new
# connection paid the is new
# connection the visit is old
# connection visit , is new
# connection , we is new
# connection we cannot is new
# connection cannot escape is new
# connection escape the is new
# connection the acquaintance is new
# connection acquaintance now is new
# connection now . is old
# connection . The is old
# connection The astonishment is new
# connection astonishment of is new
# connection of the is old
# connection the ladies is new
# connection ladies was is new
# connection was just is new
# connection just what is new
# connection what he is new
# connection he wished is new
# connection wished ; is new
# connection ; that is old
# connection that of is new
# connection of Mrs is new
# connection Mrs . is old
# connection . Bennet is old
# connection Bennet perhaps is new
# connection perhaps surpassing is new
# connection surpassing the is new
# connection the rest is new
# connection rest ; is new
# connection ; though is old
# connection though , is new
# connection , when is old
# connection when the is new
# connection the first is new
# connection first tumult is new
# connection tumult of is new
# connection of joy is new
# connection joy was is new
# connection was over is new
# connection over , is new
# connection , she is old
# connection she began is new
# connection began to is new
# connection to declare is new
# connection declare that is new
# connection that it is new
# connection it was is new
# connection was what is new
# connection what she is new
# connection she had is old
# connection had expected is new
# connection expected all is new
# connection all the is new
# connection the while is new
# connection while . is new
# connection . How is new
# connection How good is new
# connection good it is new
# connection it was is old
# connection was in is new
# connection in you is new
# connection you , is old
# connection , my is old
# connection my dear is old
# connection dear Mr is old
# connection Mr . is old
# connection . Bennet is old
# connection Bennet ! is new
# connection ! But is old
# connection But I is old
# connection I knew is new
# connection knew I is new
# connection I should is new
# connection should persuade is new
# connection persuade you is new
# connection you at is new
# connection at last is old
# connection last . is new
# connection . I is old
# connection I was is new
# connection was sure is new
# connection sure you is new
# connection you loved is new
# connection loved your is new
# connection your girls is new
# connection girls too is new
# connection too well is new
# connection well to is new
# connection to neglect is new
# connection neglect such is new
# connection such an is new
# connection an acquaintance is new
# connection acquaintance . is new
# connection . Well is new
# connection Well , is new
# connection , how is old
# connection how pleased is new
# connection pleased I is new
# connection I am is old
# connection am ! is new
# connection ! and is new
# connection and it is new
# connection it is is old
# connection is such is new
# connection such a is old
# connection a good is old
# connection good joke is new
# connection joke , is new
# connection , too is new
# connection too , is new
# connection , that is old
# connection that you is old
# connection you should is new
# connection should have is new
# connection have gone is new
# connection gone this is new
# connection this morning is old
# connection morning and is new
# connection and never is new
# connection never said is new
# connection said a is new
# connection a word is new
# connection word about is new
# connection about it is old
# connection it till is new
# connection till now is new
# connection now . is old
# connection . Now is new
# connection Now , is new
# connection , Kitty is old
# connection Kitty , is old
# connection , you is old
# connection you may is old
# connection may cough is new
# connection cough as is new
# connection as much is old
# connection much as is new
# connection as you is old
# connection you choose is new
# connection choose , is new
# connection , said is old
# ...
# connection a sheet is old
# connection sheet of is old
# connection of paper is new
# connection paper , is old
# connection , wrote is new
# connection wrote a is new
# connection a short is old
# connection short letter is old
# connection letter to is old
# connection to her is old
# connection her aunt is old
# connection aunt , is old
# connection , to is old
# connection to request is old
# connection request an is new
# connection an explanation is old
# connection explanation of is old
# connection of what is old
# connection what Lydia is new
# connection Lydia had is old
# connection had dropt is new
# connection dropt , is new
# connection , if is old
# connection if it is old
# connection it were is old
# connection were compatible is new
# connection compatible with is old
# connection with the is old
# connection the secrecy is new
# connection secrecy which is new
# connection which had is old
# connection had been is old
# connection been intended is new
# connection intended . is new
# connection . You is old
# connection You may is old
# connection may readily is new
# connection readily comprehend is old
# connection comprehend , is old
# connection , she is old
# connection she added is old
# connection added , is old
# connection , what is old
# connection what my is old
# connection my curiosity is new
# connection curiosity must is new
# connection must be is old
# connection be to is old
# connection to know is old
# connection know how is old
# connection how a is new
# connection a person is old
# connection person unconnected is new
# connection unconnected with is old
# connection with any is old
# connection any of is old
# connection of us is old
# connection us , is old
# connection , and is old
# connection and (comparatively is new
# connection (comparatively speaking) is new
# connection speaking) a is new
# connection a stranger is old
# connection stranger to is old
# connection to our is old
# connection our family is old
# connection family , is old
# connection , should is old
# connection should have is old
# connection have been is old
# connection been amongst is new
# connection amongst you is new
# connection you at is old
# connection at such is old
# connection such a is old
# connection a time is old
# connection time . is old
# connection . Pray is old
# connection Pray write is new
# connection write instantly is new
# connection instantly , is old
# connection , and is old
# connection and let is old
# connection let me is old
# connection me understand is new
# connection understand it—unless is new
# connection it—unless it is new
# connection it is is old
# connection is , is old
# connection , for is old
# connection for very is new
# connection very cogent is new
# connection cogent reasons is new
# connection reasons , is new
# connection , to is old
# connection to remain is old
# connection remain in is old
# connection in the is old
# connection the secrecy is old
# connection secrecy which is old
# connection which Lydia is old
# connection Lydia seems is new
# connection seems to is old
# connection to think is old
# connection think necessary is new
# connection necessary ; is old
# connection ; and is old
# connection and then is old
# connection then I is old
# connection I must is old
# connection must endeavour is old
# connection endeavour to is old
# connection to be is old
# connection be satisfied is old
# connection satisfied with is old
# connection with ignorance is new
# connection ignorance . is new
# connection . Not is old
# connection Not that is old
# connection that I is old
# connection I _shall_ is new
# connection _shall_ , is new
# connection , though is old
# connection though , is old
# connection , she is old
# connection she added is old
# connection added to is old
# connection to herself is old
# connection herself , is old
# connection , as is old
# connection as she is old
# connection she finished is old
# connection finished the is old
# connection the letter is old
# connection letter ; is old
# connection ; and is old
# connection and my is old
# connection my dear is old
# connection dear aunt is old
# connection aunt , is old
# connection , if is old
# connection if you is old
# connection you do is old
# connection do not is old
# connection not tell is old
# connection tell me is old
# connection me in is old
# connection in an is old
# connection an honourable is new
# connection honourable manner is new
# connection manner , is old
# connection , I is old
# connection I shall is old
# connection shall certainly is old
# connection certainly be is old
# connection be reduced is new
# connection reduced to is new
# connection to tricks is new
# connection tricks and is new
# connection and stratagems is new
# connection stratagems to is new
# connection to find is old
# connection find it is old
# connection it out is old
# connection out . is old
# connection . Jane’s is old
# connection Jane’s delicate is new
# connection delicate sense is new
# connection sense of is old
# connection of honour is old
# connection honour would is new
# connection would not is old
# connection not allow is old
# connection allow her is old
# connection her to is old
# connection to speak is old
# connection speak to is old
# connection to Elizabeth is old
# connection Elizabeth privately is new
# connection privately of is new
# connection of what is old
# connection what Lydia is old
# connection Lydia had is old
# connection had let is new
# connection let fall is new
# connection fall ; is new
# connection ; Elizabeth is new
# connection Elizabeth was is old
# connection was glad is old
# connection glad of is old
# connection of it is old
# connection it ;—till is new
# connection ;—till it is new
# connection it appeared is old
# connection appeared whether is new
# connection whether her is old
# connection her inquiries is old
# connection inquiries would is new
# connection would receive is old
# connection receive any is new
# connection any satisfaction is new
# connection satisfaction , is old
# connection , she is old
# connection she had is old
# connection had rather is old
# connection rather be is old
# connection be without is old
# connection without a is old
# connection a confidante is new
# connection confidante . is new
# connection . Elizabeth is old
# connection Elizabeth had is old
# connection had the is old
# connection the satisfaction is old
# connection satisfaction of is old
# connection of receiving is old
# connection receiving an is old
# connection an answer is old
# connection answer to is old
# connection to her is old
# connection her letter is old
# connection letter as is new
# connection as soon is old
# connection soon as is old
# connection as she is old
# connection she possibly is new
# connection possibly could is new
# connection could . is old
# connection . She is old
# connection She was is old
# connection was no is old
# connection no sooner is old
# connection sooner in is new
# connection in possession is old
# connection possession of is old
# connection of it is old
# connection it than is old
# connection than , is new
# connection , hurrying is new
# connection hurrying into is new
# connection into the is old
# connection the little is old
# connection little copse is old
# connection copse , is new
# connection , where is old
# connection where she is old
# connection she was is old
# connection was least is old
# connection least likely is new
# connection likely to is old
# connection to be is old
# connection be interrupted is new
# connection interrupted , is new
# connection , she is old
# connection she sat is old
# connection sat down is old
# connection down on is old
# connection on one is old
# connection one of is old
# connection of the is old
# connection the benches is new
# connection benches and is new
# connection and prepared is old
# connection prepared to is old
# connection to be is old
# connection be happy is old
# connection happy ; is old
# connection ; for is old
# connection for the is old
# connection the length is old
# connection length of is old
# connection of the is old
# connection the letter is old
# connection letter convinced is new
# connection convinced her is old
# connection her that is old
# connection that it is old
# connection it did is old
# connection did not is old
# connection not contain is new
# connection contain a is old
# connection a denial is new
# connection denial . is new
# connection . Gracechurch is old
# connection Gracechurch Street is old
# connection Street , is old
# connection , _Sept_ is new
# connection _Sept_ . is new
# connection . 6 is new
# connection 6 . is new
# connection . My is old
# connection My dear is old
# connection dear Niece is new
# connection Niece , is new
# connection , I is old
# connection I have is old
# connection have just is old
# connection just received is old
# connection received your is new
# connection your letter is new
# connection letter , is old
# connection , and is old
# connection and shall is old
# connection shall devote is new
# connection devote this is new
# connection this whole is new
# connection whole morning is old
# connection morning to is old
# connection to answering is new
# connection answering it is new
# connection it , is old
# connection , as is old
# connection as I is old
# connection I foresee is new
# connection foresee that is new
# connection that a is old
# connection a _little_ is new
# connection _little_ writing is new
# connection writing will is new
# connection will not is old
# connection not comprise is new
# connection comprise what is new
# connection what I is old
# connection I have is old
# connection have to is old
# connection to tell is old
# connection tell you is old
# connection you . is old
# connection . I is old
# connection I must is old
# connection must confess is old
# connection confess myself is old
# connection myself surprised is new
# connection surprised by is old
# connection by your is old
# connection your application is new
# connection application ; is new
# connection ; I is old
# connection I did is old
# connection did not is old
# connection not expect is old
# connection expect it is old
# connection it from is old
# connection from _you_ is old
# connection _you_ . is old
# connection . Don’t is old
# connection Don’t think is new
# connection think me is old
# connection me angry is new
# connection angry , is new
# connection , however is old
# connection however , is old
# connection , for is old
# connection for I is old
# connection I only is old
# connection only mean is new
# connection mean to is old
# connection to let is old
# connection let you is new
# connection you know is old
# connection know that is old
# connection that I is old
# connection I had is old
# connection had not is old
# connection not imagined is new
# connection imagined such is new
# connection such inquiries is new
# connection inquiries to is old
# connection to be is old
# connection be necessary is old
# connection necessary on is new
# connection on _your_ is old
# connection _your_ side is new
# connection side . is old
# connection . If is old
# connection If you is old
# connection you do is old
# connection do not is old
# connection not choose is old
# connection choose to is old
# connection to understand is old
# connection understand me is new
# connection me , is old
# connection , forgive is new
# ----------------------------------------------------------------
# KeyboardInterrupt              Traceback (most recent call last)
# <ipython-input-25-97571ccdbbe4> in <module>
#       2 context_dimension  = 75
#       3
# ----> 4 update_graph_db(corpus,words)
#       5
#       6 end = time.time() - start
#
# <ipython-input-16-ea1c5749d2ca> in update_graph_db(corpus, collection)
#      42         word_1 = corpus[pair[0]]
#      43         word_2 = corpus[pair[1]]
# ---> 44         touch_connection_db(collection,word_1,word_2)
#      45
#
# <ipython-input-16-ea1c5749d2ca> in touch_connection_db(collection, word_1, word_2)
#      13 def touch_connection_db(collection,word_1,word_2):
#      14
# ---> 15     find_connection = collection.find_one({'word': word_1,'connection': word_2})
#      16
#      17     if find_connection == None:
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/collection.py in find_one(self, filter, *args, **kwargs)
#    1317
#    1318         cursor = self.find(filter, *args, **kwargs)
# -> 1319         for result in cursor.limit(-1):
#    1320             return result
#    1321         return None
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1205         if self.__empty:
#    1206             raise StopIteration
# -> 1207         if len(self.__data) or self._refresh():
#    1208             if self.__manipulate:
#    1209                 _db = self.__collection.database
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1122                                   self.__collection.database.client,
#    1123                                   self.__allow_disk_use)
# -> 1124             self.__send_message(q)
#    1125         elif self.__id:  # Get More
#    1126             if self.__limit:
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
#     999             response = client._run_operation_with_response(
#    1000                 operation, self._unpack_response, exhaust=self.__exhaust,
# -> 1001                 address=self.__address)
#    1002         except OperationFailure:
#    1003             self.__killed = True
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/mongo_client.py in _run_operation_with_response(self, operation, unpack_res, exhaust, address)
#    1370             address=address,
#    1371             retryable=isinstance(operation, message._Query),
# -> 1372             exhaust=exhaust)
#    1373
#    1374     def _retry_with_session(self, retryable, func, session, bulk):
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1469                         # not support retryable reads, raise the last error.
#    1470                         raise last_error
# -> 1471                     return func(session, server, sock_info, slave_ok)
#    1472             except ServerSelectionTimeoutError:
#    1473                 if retrying:
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, slave_ok)
#    1364                 self._event_listeners,
#    1365                 exhaust,
# -> 1366                 unpack_res)
#    1367
#    1368         return self._retryable_read(
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/server.py in run_operation_with_response(self, sock_info, operation, set_slave_okay, listeners, exhaust, unpack_res)
#     115             if send_message:
#     116                 sock_info.send_message(data, max_doc_size)
# --> 117                 reply = sock_info.receive_message(request_id)
#     118             else:
#     119                 reply = sock_info.receive_message(None)
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     724             return receive_message(self, request_id, self.max_message_size)
#     725         except BaseException as error:
# --> 726             self._raise_connection_failure(error)
#     727
#     728     def _raise_if_not_writable(self, unacknowledged):
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/pool.py in receive_message(self, request_id)
#     722         """
#     723         try:
# --> 724             return receive_message(self, request_id, self.max_message_size)
#     725         except BaseException as error:
#     726             self._raise_connection_failure(error)
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     193     # Ignore the response's request id.
#     194     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 195         _receive_data_on_socket(sock_info, 16, deadline))
#     196     # No request_id for exhaust cursor "getMore".
#     197     if request_id is not None:
#
# ~/py_envs/Anuvaad/lib/python3.6/site-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     284             try:
#     285                 wait_for_read(sock_info, deadline)
# --> 286                 chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     287             except (IOError, OSError) as exc:
#     288                 if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %%
import numpy as np
